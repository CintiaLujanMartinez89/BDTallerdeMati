-- %% [markdown]
-- # [El_TALLER_DE_MATI]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [El_TALLER_DE_MATI]    Script Date: 1/10/2024 09:45:48 ******/
CREATE DATABASE [El_TALLER_DE_MATI]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'El_TALLER_DE_MATI_BD', FILENAME = N'C:\El Taller de Mati\El_TALLER_DE_MATI.mdf' , SIZE = 73728KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'El_TALLER_DE_MATI_log', FILENAME = N'C:\El Taller de Mati\El_TALLER_DE_MATI_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [El_TALLER_DE_MATI].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET ARITHABORT OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET  ENABLE_BROKER 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET  MULTI_USER 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET DB_CHAINING OFF 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET QUERY_STORE = ON
GO
ALTER DATABASE [El_TALLER_DE_MATI] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[ADMINISTRADORES]

-- %%
USE [El_TALLER_DE_MATI]
GO

-- %%
/****** Object:  Table [dbo].[ADMINISTRADORES]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ADMINISTRADORES](
	[Usuario_A] [varchar](10) NULL,
	[Password_A] [varchar](10) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CLIENTES]

-- %%
/****** Object:  Table [dbo].[CLIENTES]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CLIENTES](
	[Dni_CLI] [varchar](10) NOT NULL,
	[Nombre_CLI] [varchar](20) NOT NULL,
	[Apellido_CLI] [varchar](20) NOT NULL,
	[Domicilio_CLI] [varchar](50) NOT NULL,
	[Telefono_CLI] [varchar](15) NOT NULL,
	[Email] [varchar](30) NOT NULL,
	[Estado_CLI] [bit] NOT NULL,
	[HashContraseña_CLI] [varchar](255) NULL,
 CONSTRAINT [PK_CLIENTES] PRIMARY KEY CLUSTERED 
(
	[Dni_CLI] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CLIENTES_X_MOTOS]

-- %%
/****** Object:  Table [dbo].[CLIENTES_X_MOTOS]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CLIENTES_X_MOTOS](
	[Dni_CXM] [varchar](10) NOT NULL,
	[Patente_Moto_CXM] [varchar](10) NOT NULL,
 CONSTRAINT [PK_CLIENTES_X_MOTOS] PRIMARY KEY CLUSTERED 
(
	[Dni_CXM] ASC,
	[Patente_Moto_CXM] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DIA]

-- %%
/****** Object:  Table [dbo].[DIA]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DIA](
	[Dia_D] [date] NOT NULL,
 CONSTRAINT [PK_DIA] PRIMARY KEY CLUSTERED 
(
	[Dia_D] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DIA_X_HORA]

-- %%
/****** Object:  Table [dbo].[DIA_X_HORA]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DIA_X_HORA](
	[Dia_DXH] [date] NOT NULL,
	[Hora_DXH] [time](7) NOT NULL,
 CONSTRAINT [PK_DIA_X_HORA] PRIMARY KEY CLUSTERED 
(
	[Dia_DXH] ASC,
	[Hora_DXH] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HISTORIAL]

-- %%
/****** Object:  Table [dbo].[HISTORIAL]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HISTORIAL](
	[Id_Historial_H] [varchar](10) NOT NULL,
	[Dni_H] [varchar](10) NOT NULL,
	[Patente_Moto_H] [varchar](10) NOT NULL,
	[Estado_H] [bit] NULL,
 CONSTRAINT [PK_HISTORIAL_1] PRIMARY KEY CLUSTERED 
(
	[Id_Historial_H] ASC,
	[Dni_H] ASC,
	[Patente_Moto_H] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HISTORIAL_X_SERVICIOS]

-- %%
/****** Object:  Table [dbo].[HISTORIAL_X_SERVICIOS]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HISTORIAL_X_SERVICIOS](
	[Id_Historial_HXS] [varchar](10) NOT NULL,
	[Dni_HXS] [varchar](10) NOT NULL,
	[Patente_Moto_HXS] [varchar](10) NOT NULL,
	[Id_Servicio_HXS] [varchar](10) NOT NULL,
	[Detalle_HXS] [varchar](200) NULL,
	[Fecha_Realizacion_HXS] [date] NOT NULL,
	[Kilometraje_HXS] [int] NOT NULL,
 CONSTRAINT [PK_HISTORIAL_X_SERVICIOS_1] PRIMARY KEY CLUSTERED 
(
	[Id_Historial_HXS] ASC,
	[Kilometraje_HXS] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HORA]

-- %%
/****** Object:  Table [dbo].[HORA]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HORA](
	[Hora_H] [time](7) NOT NULL,
 CONSTRAINT [PK_HORA] PRIMARY KEY CLUSTERED 
(
	[Hora_H] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MOTOS]

-- %%
/****** Object:  Table [dbo].[MOTOS]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MOTOS](
	[Patente_Moto_M] [varchar](10) NOT NULL,
	[Marca_M] [varchar](20) NOT NULL,
	[Modelo_M] [varchar](20) NOT NULL,
	[Km_Inicial_M] [int] NULL,
	[Estado_M] [bit] NOT NULL,
 CONSTRAINT [PK_MOTOS] PRIMARY KEY CLUSTERED 
(
	[Patente_Moto_M] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SERVICIOS]

-- %%
/****** Object:  Table [dbo].[SERVICIOS]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SERVICIOS](
	[Id_Servicio_S] [varchar](10) NOT NULL,
	[Nombre_S] [varchar](50) NOT NULL,
	[Detalle_S] [varchar](250) NULL,
	[Precio_S] [float] NULL,
 CONSTRAINT [FK_SERVICIOS] PRIMARY KEY CLUSTERED 
(
	[Id_Servicio_S] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TURNOS]

-- %%
/****** Object:  Table [dbo].[TURNOS]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TURNOS](
	[Dia_T] [date] NOT NULL,
	[Hora_T] [time](7) NOT NULL,
	[Dni_T] [varchar](10) NOT NULL,
	[Patente_Moto_T] [varchar](10) NULL,
	[Id_Servicio_T] [varchar](10) NOT NULL,
	[Observacion_T] [varchar](200) NULL,
	[Asistencia_T] [bit] NOT NULL,
	[Id_Turno_T] [int] IDENTITY(1,1) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id_Turno_T] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__SERVICIOS__Preci__534D60F1]

-- %%
ALTER TABLE [dbo].[SERVICIOS] ADD  DEFAULT ((0.0)) FOR [Precio_S]
GO

-- %% [markdown]
-- # [FK_CLIENTES_X_MOTOS_CLIENTES]

-- %%
ALTER TABLE [dbo].[CLIENTES_X_MOTOS]  WITH CHECK ADD  CONSTRAINT [FK_CLIENTES_X_MOTOS_CLIENTES] FOREIGN KEY([Dni_CXM])
REFERENCES [dbo].[CLIENTES] ([Dni_CLI])
GO
ALTER TABLE [dbo].[CLIENTES_X_MOTOS] CHECK CONSTRAINT [FK_CLIENTES_X_MOTOS_CLIENTES]
GO

-- %% [markdown]
-- # [FK_CLIENTES_X_MOTOS_MOTOS]

-- %%
ALTER TABLE [dbo].[CLIENTES_X_MOTOS]  WITH CHECK ADD  CONSTRAINT [FK_CLIENTES_X_MOTOS_MOTOS] FOREIGN KEY([Patente_Moto_CXM])
REFERENCES [dbo].[MOTOS] ([Patente_Moto_M])
GO
ALTER TABLE [dbo].[CLIENTES_X_MOTOS] CHECK CONSTRAINT [FK_CLIENTES_X_MOTOS_MOTOS]
GO

-- %% [markdown]
-- # [FK_DIA_X_HORA_DIA]

-- %%
ALTER TABLE [dbo].[DIA_X_HORA]  WITH CHECK ADD  CONSTRAINT [FK_DIA_X_HORA_DIA] FOREIGN KEY([Dia_DXH])
REFERENCES [dbo].[DIA] ([Dia_D])
GO
ALTER TABLE [dbo].[DIA_X_HORA] CHECK CONSTRAINT [FK_DIA_X_HORA_DIA]
GO

-- %% [markdown]
-- # [FK_DIA_X_HORA_HORA]

-- %%
ALTER TABLE [dbo].[DIA_X_HORA]  WITH CHECK ADD  CONSTRAINT [FK_DIA_X_HORA_HORA] FOREIGN KEY([Hora_DXH])
REFERENCES [dbo].[HORA] ([Hora_H])
GO
ALTER TABLE [dbo].[DIA_X_HORA] CHECK CONSTRAINT [FK_DIA_X_HORA_HORA]
GO

-- %% [markdown]
-- # [FK_HISTORIAL_CLIENTES_X_MOTOS]

-- %%
ALTER TABLE [dbo].[HISTORIAL]  WITH CHECK ADD  CONSTRAINT [FK_HISTORIAL_CLIENTES_X_MOTOS] FOREIGN KEY([Dni_H], [Patente_Moto_H])
REFERENCES [dbo].[CLIENTES_X_MOTOS] ([Dni_CXM], [Patente_Moto_CXM])
GO
ALTER TABLE [dbo].[HISTORIAL] CHECK CONSTRAINT [FK_HISTORIAL_CLIENTES_X_MOTOS]
GO

-- %% [markdown]
-- # [FK_HISTORIAL_X_SERVICIOS_SERVICIOS]

-- %%
ALTER TABLE [dbo].[HISTORIAL_X_SERVICIOS]  WITH CHECK ADD  CONSTRAINT [FK_HISTORIAL_X_SERVICIOS_SERVICIOS] FOREIGN KEY([Id_Historial_HXS], [Dni_HXS], [Patente_Moto_HXS])
REFERENCES [dbo].[HISTORIAL] ([Id_Historial_H], [Dni_H], [Patente_Moto_H])
GO
ALTER TABLE [dbo].[HISTORIAL_X_SERVICIOS] CHECK CONSTRAINT [FK_HISTORIAL_X_SERVICIOS_SERVICIOS]
GO

-- %% [markdown]
-- # [FK_HISTORIAL_X_SERVICIOS_SERVICIOS1]

-- %%
ALTER TABLE [dbo].[HISTORIAL_X_SERVICIOS]  WITH CHECK ADD  CONSTRAINT [FK_HISTORIAL_X_SERVICIOS_SERVICIOS1] FOREIGN KEY([Id_Servicio_HXS])
REFERENCES [dbo].[SERVICIOS] ([Id_Servicio_S])
GO
ALTER TABLE [dbo].[HISTORIAL_X_SERVICIOS] CHECK CONSTRAINT [FK_HISTORIAL_X_SERVICIOS_SERVICIOS1]
GO

-- %% [markdown]
-- # [FK_TURNOS_CLIENTES_X_MOTOS]

-- %%
ALTER TABLE [dbo].[TURNOS]  WITH CHECK ADD  CONSTRAINT [FK_TURNOS_CLIENTES_X_MOTOS] FOREIGN KEY([Dni_T], [Patente_Moto_T])
REFERENCES [dbo].[CLIENTES_X_MOTOS] ([Dni_CXM], [Patente_Moto_CXM])
GO
ALTER TABLE [dbo].[TURNOS] CHECK CONSTRAINT [FK_TURNOS_CLIENTES_X_MOTOS]
GO

-- %% [markdown]
-- # [FK_TURNOS_DIA_X_HORA]

-- %%
ALTER TABLE [dbo].[TURNOS]  WITH CHECK ADD  CONSTRAINT [FK_TURNOS_DIA_X_HORA] FOREIGN KEY([Dia_T], [Hora_T])
REFERENCES [dbo].[DIA_X_HORA] ([Dia_DXH], [Hora_DXH])
GO
ALTER TABLE [dbo].[TURNOS] CHECK CONSTRAINT [FK_TURNOS_DIA_X_HORA]
GO

-- %% [markdown]
-- # [FK_TURNOS_SERVICIOS]

-- %%
ALTER TABLE [dbo].[TURNOS]  WITH CHECK ADD  CONSTRAINT [FK_TURNOS_SERVICIOS] FOREIGN KEY([Id_Servicio_T])
REFERENCES [dbo].[SERVICIOS] ([Id_Servicio_S])
GO
ALTER TABLE [dbo].[TURNOS] CHECK CONSTRAINT [FK_TURNOS_SERVICIOS]
GO

-- %% [markdown]
-- # [dbo].[AgregarCliente_X_Moto]

-- %%
/****** Object:  StoredProcedure [dbo].[AgregarCliente_X_Moto]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[AgregarCliente_X_Moto]
    @patente VARCHAR(10),
    @dni VARCHAR(10)
AS
BEGIN
    INSERT INTO CLIENTES_X_MOTOS (Dni_CXM, Patente_Moto_CXM)
    VALUES (@dni, @patente);
END;
GO

-- %% [markdown]
-- # [dbo].[AgregarMoto]

-- %%
/****** Object:  StoredProcedure [dbo].[AgregarMoto]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[AgregarMoto]
    @patente VARCHAR(10),
    @marca VARCHAR(20),
    @modelo VARCHAR(20),
    @km INT

AS
BEGIN
    INSERT INTO Motos (Patente_Moto_M, Marca_M, Modelo_M, Km_Inicial_M,Estado_M)
    VALUES (@patente, @marca, @modelo, @km,1);
END;
GO

-- %% [markdown]
-- # [dbo].[ObtenerMotosPorDni]

-- %%
/****** Object:  StoredProcedure [dbo].[ObtenerMotosPorDni]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ObtenerMotosPorDni]
    @dni VARCHAR(10)
AS
BEGIN
    SELECT 
        Patente_Moto_CXM,
        Marca_M,
        Modelo_M,
      Nombre_S,
   FORMAT(Fecha_Realizacion_HXS, 'dd/MM/yyyy') AS Fecha_Realizacion_HXS
    FROM CLIENTES_X_MOTOS AS cxm
   INNER JOIN Motos AS m ON cxm.Patente_Moto_CXM = m.Patente_Moto_M
   LEFT JOIN HISTORIAL_X_SERVICIOS hxs ON m.Patente_Moto_M = hxs.Patente_Moto_HXS
   LEFT JOIN SERVICIOS AS s ON s.Id_Servicio_S = hxs.Id_Servicio_HXS
    WHERE Dni_CXM =@dni AND Estado_M=1;
END;
GO

-- %% [markdown]
-- # [dbo].[ObtenerTablaHistorial]

-- %%
/****** Object:  StoredProcedure [dbo].[ObtenerTablaHistorial]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ObtenerTablaHistorial]

AS
BEGIN
 
SELECT Dni_HXS,Nombre_CLI+' '+Apellido_CLI as Nombre_CLI,Detalle_HXS,Patente_Moto_HXS,Marca_M,Modelo_M, FORMAT(Fecha_Realizacion_HXS, 'dd/MM/yyyy') AS Fecha_Realizacion_HXS,Kilometraje_HXS,Nombre_S
FROM HISTORIAL_X_SERVICIOS inner join CLIENTES on Dni_HXS=Dni_CLI
							inner join MOTOS on Patente_Moto_HXS=Patente_Moto_M
							inner join SERVICIOS on Id_Servicio_S=Id_Servicio_HXS
END
GO

-- %% [markdown]
-- # [dbo].[ReservarTurno]

-- %%
/****** Object:  StoredProcedure [dbo].[ReservarTurno]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[ReservarTurno]
    @Dia DATE,
    @Hora TIME,
    @Dni VARCHAR(10),
    @Patente VARCHAR(10),
    @IdServicio VARCHAR(10),
    @Observacion VARCHAR(200),
    @Asistencia BIT
AS
BEGIN
    INSERT INTO TURNOS
        (Dia_T, Hora_T, Dni_T, Patente_Moto_T, Id_Servicio_T, Observacion_T, Asistencia_T)
    VALUES
        (@Dia, @Hora, @Dni, @Patente, @IdServicio, @Observacion, @Asistencia);
END;
GO

-- %% [markdown]
-- # [dbo].[spActualizarServicios]

-- %%
/****** Object:  StoredProcedure [dbo].[spActualizarServicios]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[spActualizarServicios]
    @idServicio VARCHAR(10),
    @Nombre VARCHAR(50),
    @Descripcion VARCHAR(250),
    @Precio FLOAT
AS
BEGIN
    UPDATE SERVICIOS
    SET
        Nombre_S = @Nombre,
        Detalle_S = @Descripcion,
        Precio_S = @Precio
    WHERE Id_Servicio_S = @idServicio
END
GO

-- %% [markdown]
-- # [dbo].[spAgregarFechaHora]

-- %%
/****** Object:  StoredProcedure [dbo].[spAgregarFechaHora]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[spAgregarFechaHora]
    @Dia DATE,
    @Hora TIME
AS
BEGIN
    INSERT INTO DIA_X_HORA (Dia_DXH, Hora_DXH)
    VALUES (@Dia, @Hora);
END
GO

-- %% [markdown]
-- # [dbo].[spAgregarHistorial]

-- %%
/****** Object:  StoredProcedure [dbo].[spAgregarHistorial]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[spAgregarHistorial]
    @Dni_H VARCHAR(10),
    @Patente_Moto_H VARCHAR(10),
    @Estado_H BIT
AS
BEGIN
    DECLARE @NuevoId VARCHAR(10);
    
    -- Obtener el último Id_Historial_H
    DECLARE @UltimoId INT;
    SELECT @UltimoId = MAX(CAST(SUBSTRING(Id_Historial_H, 2, LEN(Id_Historial_H) - 1) AS INT))
    FROM HISTORIAL;

    -- Generar el nuevo Id_Historial_H
    SET @NuevoId = 'H' + CAST(@UltimoId + 1 AS VARCHAR);

    -- Insertar el nuevo registro
    INSERT INTO [dbo].[HISTORIAL] ([Id_Historial_H], [Dni_H], [Patente_Moto_H], [Estado_H])
    VALUES (@NuevoId, @Dni_H, @Patente_Moto_H, @Estado_H);
END
GO

-- %% [markdown]
-- # [dbo].[spAgregarServicios]

-- %%
/****** Object:  StoredProcedure [dbo].[spAgregarServicios]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[spAgregarServicios]
    @idServicio VARCHAR(10),
    @Nombre VARCHAR(50),
    @Descripcion VARCHAR(250),
    @Precio FLOAT
AS
BEGIN
    INSERT INTO SERVICIOS (Id_Servicio_S, Nombre_S, Detalle_S, Precio_S)
    VALUES (@idServicio, @Nombre, @Descripcion, @Precio)
END
GO

-- %% [markdown]
-- # [dbo].[spCambiarAsistencia]

-- %%
/****** Object:  StoredProcedure [dbo].[spCambiarAsistencia]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[spCambiarAsistencia]
    @IdTurno INT,
    @Dia DATE,
    @Hora TIME
AS
BEGIN
    SET NOCOUNT ON;

    UPDATE TURNOS
    SET Asistencia_T = CASE 
                          WHEN Asistencia_T = 1 THEN 0 
                          ELSE 1 
                       END
    WHERE Id_Turno_T = @IdTurno AND Dia_T = @Dia AND Hora_T = @Hora;
	SELECT @@ROWCOUNT AS FilasAfectadas;
END
GO

-- %% [markdown]
-- # [dbo].[spCargarTablaCLIXMOT]

-- %%
/****** Object:  StoredProcedure [dbo].[spCargarTablaCLIXMOT]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[spCargarTablaCLIXMOT]
AS 
BEGIN 
Select Dni_CXM,Patente_Moto_CXM, Nombre_CLI + ' ' + Apellido_CLI AS Nombre_CLI, Marca_M,Modelo_M from Clientes_X_Motos inner join Clientes on Dni_CXM=Dni_CLI
inner join MOTOS on Patente_Moto_CXM=Patente_Moto_M
order by Dni_CXM
END
GO

-- %% [markdown]
-- # [dbo].[spEliminar]

-- %%
/****** Object:  StoredProcedure [dbo].[spEliminar]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[spEliminar]
    @Id_Turno INT
AS
BEGIN

    DELETE FROM [dbo].[TURNOS]
    WHERE [Id_Turno_T] = @Id_Turno;
END
GO

-- %% [markdown]
-- # [dbo].[spEliminarServicios]

-- %%
/****** Object:  StoredProcedure [dbo].[spEliminarServicios]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[spEliminarServicios]
    @idServicio VARCHAR(10)
AS
BEGIN
  
    DELETE FROM SERVICIOS
    WHERE [Id_Servicio_S] = @idServicio;
END

GO

-- %% [markdown]
-- # [dbo].[spInsertarCliente]

-- %%
/****** Object:  StoredProcedure [dbo].[spInsertarCliente]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[spInsertarCliente]
    @Dni VARCHAR(10),
    @Nombre VARCHAR(20),
    @Apellido VARCHAR(20),
    @Domicilio VARCHAR(50),
    @Telefono VARCHAR(15),
    @Email VARCHAR(30),
    @HashContraseña VARCHAR(255)
AS
BEGIN
    -- Verificar si el DNI ya existe
    IF EXISTS (SELECT 1 FROM CLIENTES WHERE Dni_CLI = @Dni)
    BEGIN
        -- El DNI ya existe, devolver 2
        RETURN 2;
    END
    ELSE
    BEGIN
        -- Insertar el nuevo cliente
        INSERT INTO CLIENTES (Dni_CLI, Nombre_CLI, Apellido_CLI, Domicilio_CLI, Telefono_CLI, Email, Estado_CLI, HashContraseña_CLI)
        VALUES (@Dni, @Nombre, @Apellido, @Domicilio, @Telefono, @Email, 1, @HashContraseña);
        
        -- Devolver 1 para indicar que la inserción fue exitosa
        RETURN 1;
    END
END
GO

-- %% [markdown]
-- # [dbo].[spObtenerServicios]

-- %%
/****** Object:  StoredProcedure [dbo].[spObtenerServicios]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[spObtenerServicios]
AS
BEGIN
	SELECT Id_Servicio_S,Nombre_S,Detalle_S,Precio_S
	from SERVICIOS
END
---------
GO

-- %% [markdown]
-- # [dbo].[spObtenerTurnosAsignados]

-- %%
/****** Object:  StoredProcedure [dbo].[spObtenerTurnosAsignados]    Script Date: 1/10/2024 09:45:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[spObtenerTurnosAsignados]
AS
BEGIN
 

    SELECT 
        Id_Turno_T,
       FORMAT(Dia_T, 'dd/MM/yyyy') AS Dia_T,
          Hora_T, 
        Nombre_CLI + ' ' + Apellido_CLI AS Nombre_CLI,
        Patente_Moto_T,
        Marca_M,
        Modelo_M,
        Nombre_S,
        Observacion_T,
        Asistencia_T
    FROM 
        TURNOS
    INNER JOIN 
        CLIENTES ON Dni_CLI = Dni_T
    INNER JOIN 
        CLIENTES_X_MOTOS ON Dni_CXM = Dni_T
    INNER JOIN 
        MOTOS ON Patente_Moto_M = Patente_Moto_T
    INNER JOIN 
        SERVICIOS ON Id_Servicio_S = Id_Servicio_T
    GROUP BY 
        Id_Turno_T,
        Dia_T,
        Hora_T,
        Nombre_CLI,
        Apellido_CLI,
        Marca_M,
        Modelo_M,
        Observacion_T,
        Nombre_S,
        Asistencia_T,
        Patente_Moto_T
END
GO

-- %% [markdown]
-- # [El_TALLER_DE_MATI]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [El_TALLER_DE_MATI] SET  READ_WRITE 
GO
